# %%
from pyspark.sql import SparkSession

# Initialisation de SparkSession
spark = SparkSession.builder \
    .appName("E_Amazing App") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/08/22 22:45:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
user_stats_df = spark.read.parquet("./data/user_stats_df_output.parquet")

# %%
user_stats_df.show(truncate=False)
# Out:
# 24/08/22 18:31:20 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +---------+------------------+------------------+------------------+------------------+------------------+------------------+---------------------+---------------------+---------------------+-----------------+-----------------+-----------------+------------+------------+------------+--------------------+------------------------+-----------------+-------------+---------------+---------------------------------+--------------------+---------------+----------------+------------+
# |user_id  |number_of_views_2m|number_of_views_5m|number_of_views_7m|number_of_carts_2m|number_of_carts_5m|number_of_carts_7m|number_of_sessions_2m|number_of_sessions_5m|number_of_sessions_7m|count_products_2m|count_products_5m|count_products_7m|avg_price_2m|avg_price_5m|avg_price_7m|total_purchase_value|days_since_last_purchase|cart_abandonments|brand_loyalty|preferred_brand|preferred_category               |avg_session_duration|most_active_day|most_active_time|user_segment|
# +---------+------------------+------------------+------------------+------------------+------------------+------------------+---------------------+---------------------+---------------------+-----------------+-----------------+-----------------+------------+------------+------------+--------------------+------------------------+-----------------+-------------+---------------+---------------------------------+--------------------+---------------+----------------+------------+
# |512499661|141               |632               |822               |8                 |12                |14                |13                   |41                   |52                   |6                |8                |12               |113.97      |106.01      |117.97      |1415.62             |47                      |2                |0.33         |panasonic      |No Category                      |10.0                |1              |afternoon       |High        |
# |512501421|111               |268               |280               |23                |42                |44                |15                   |37                   |38                   |9                |13               |13               |310.73      |294.32      |294.32      |3826.11             |0                       |31               |0.31         |evenflo        |kids.skates                      |3152.0              |2              |morning         |High        |
# |512523341|60                |757               |1092              |12                |14                |20                |12                   |84                   |107                  |11               |11               |21               |203.7       |203.7       |169.15      |3552.11             |28                      |0                |0.38         |cannondale     |appliances.kitchen.toster        |754.0               |5              |afternoon       |High        |
# |512523401|88                |127               |145               |6                 |6                 |6                 |9                    |13                   |18                   |2                |2                |2                |231.64      |231.64      |231.64      |463.28              |16                      |4                |1.0          |xiaomi         |construction.tools.light         |4.0                 |2              |morning         |Low         |
# |512554071|160               |397               |470               |20                |44                |44                |8                    |29                   |37                   |10               |16               |16               |63.38       |55.74       |55.74       |891.9               |26                      |28               |0.25         |hp             |furniture.living_room.chair      |10.0                |7              |morning         |Medium      |
# |512675591|107               |131               |175               |4                 |6                 |6                 |10                   |15                   |18                   |4                |4                |4                |154.19      |154.19      |154.19      |616.76              |42                      |2                |0.5          |stendmebel     |No Category                      |2.0                 |5              |afternoon       |Medium      |
# |512809551|95                |261               |397               |4                 |6                 |14                |6                    |29                   |48                   |2                |4                |4                |360.34      |200.16      |200.16      |800.64              |58                      |10               |0.5          |dauscher       |appliances.personal.massager     |4.0                 |4              |morning         |Medium      |
# |512821911|173               |202               |244               |12                |14                |18                |18                   |25                   |33                   |4                |4                |4                |268.31      |268.31      |268.31      |1073.22             |1                       |14               |0.5          |defender       |furniture.kitchen.table          |4061.0              |5              |morning         |High        |
# |512824141|209               |481               |569               |4                 |6                 |10                |14                   |27                   |31                   |2                |2                |2                |12.84       |12.84       |12.84       |25.68               |30                      |8                |1.0          |harper         |computers.components.power_supply|5.0                 |7              |evening         |Low         |
# |535883961|                 2|                 2|                 2|                 2|                 2|                 2|                    1|                    1|                    1|                2|                2|                2|      1737.5|      1737.5|      1737.5|              3475.0|                       8|                0|          1.0|      thermomix|       No Category|                 6.0|              4|         morning|        High|
# |538210561|                 9|                 9|                 9|                 2|                 2|                 2|                    1|                    1|                    1|                1|                1|                1|      209.53|      209.53|      209.53|              209.53|                      55|                1|          1.0|        kipardo|       No Category|                10.0|              6|         evening|         Low|
# |538588581|                 3|                34|                34|                 1|                 1|                 1|                    2|                   11|                   11|                1|                1|                1|       51.22|       51.22|       51.22|               51.22|                      18|                0|          1.0|       triangle|       No Category|                 1.0|              6|         morning|         Low|
# |540287481|               112|               175|               196|                 2|                 2|                 2|                    8|                   13|                   15|                2|                2|                2|      488.82|      488.82|      488.82|              977.64|                      46|                0|          1.0|          bosch|       No Category|                 6.0|              1|       afternoon|      Medium|
# |543581491|               149|               288|               418|                 4|                12|                30|                   21|                   48|                   69|                2|               10|               18|      279.81|      106.72|       125.4|             2257.28|                      23|               12|         0.22|         galaxy|       No Category|                 7.0|              6|         morning|        High|
# |545158751|                45|               230|               290|                 6|                24|                28|                    3|                   23|                   30|                6|               11|               18|      162.74|      116.66|       91.97|             1655.41|                      55|               10|         0.33|        samsung|       No Category|                 9.0|              6|         morning|        High|
# |546583301|               660|               956|              2227|                17|                21|                79|                   36|                   56|                  108|                2|                2|               11|       46.33|       46.33|       49.73|              546.98|                      46|               68|         0.36|         nokian|       No Category|                21.0|              1|       afternoon|      Medium|
# |548724491|              1006|              1611|              2522|                52|                70|                76|                   41|                   75|                  119|               12|               26|               32|       22.62|       45.97|       41.83|             1338.66|                      13|               44|         0.13|          vitek|       No Category|                17.0|              6|         evening|        High|
# +---------+------------------+------------------+------------------+------------------+------------------+------------------+---------------------+---------------------+---------------------+-----------------+-----------------+-----------------+------------+------------+------------+--------------------+------------------------+-----------------+-------------+---------------+------------------+--------------------+---------------+----------------+------------+
# only showing top 20 rows
# 24/08/22 21:09:27 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 1018079 ms exceeds timeout 120000 ms
# 24/08/22 21:09:27 WARN SparkContext: Killing executors is not supported by current scheduler.
# 24/08/22 21:09:27 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@2dd01a3a5230:41733
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/22 21:09:27 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@2dd01a3a5230:41733
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/22 21:09:27 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@2dd01a3a5230:41733
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/22 21:09:27 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@2dd01a3a5230:41733
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/22 21:09:27 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@2dd01a3a5230:41733
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 24/08/22 21:09:27 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# ...
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@2dd01a3a5230:41733
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 24/08/22 21:09:29 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@2dd01a3a5230:41733
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 24/08/22 21:09:29 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@2dd01a3a5230:41733
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 24/08/22 21:09:29 ERROR Executor: Exit as unable to send heartbeats to driver more than 60 times
# 24/08/22 21:09:29 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@2dd01a3a5230:41733
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more

# %%
user_stats_df.select("preferred_category").distinct().count()
# Out:
# 133

# %%
user_stats_df.select("preferred_brand").distinct().count()
# Out:
# 1660

# %%
filtered_df = spark.read.parquet("./data/filtered_df_output.parquet")

# %%
filtered_df.show(truncate=False)
# Out:
# +-------------------+----------+----------+-------------------+-----------------------------+-------+-------+---------+------------------------------------+
# |event_time         |event_type|product_id|category_id        |category_code                |brand  |price  |user_id  |user_session                        |
# |2020-02-26 15:55:22|purchase  |14400062  |2232732106943890077|appliances.kitchen.toster    |xiaomi |35.78  |614866011|9460a748-fe2b-4770-908a-3a3b15f1e5ba|
# +-------------------+----------+----------+-------------------+-----------------------------+-------+-------+---------+------------------------------------+
# only showing top 20 rows

# %%
filtered_df.select("brand").distinct().count()
# Out:
# 6040

# %%
filtered_df.filter(filtered_df["event_type"] == "purchase") \
                            .select("brand") \
                            .distinct() \
                            .count()
# Out:
# 3024

# %%
filtered_df.filter(filtered_df["event_type"] == "purchase").select("product_id", "brand").distinct().count()
# Out:
# 58218

# %%
filtered_df.select("category_id", "category_code").distinct().show()
# Out:
# [Stage 55:=====================================================>  (20 + 1) / 21]
# +-------------------+--------------------+
# |        category_id|       category_code|
# +-------------------+--------------------+
# |2053013560530830019|electronics.camer...|
# |2232732102858637897|furniture.bedroom...|
# |2232732113310843708|construction.tool...|
# |2232732120768316412|       apparel.shoes|
# |2053013566100866035|appliances.sewing...|
# |2110187395394568257|appliances.kitche...|
# |2135658545767514950|     apparel.costume|
# |2053013553425678619|     apparel.costume|
# |2232732102950912587|appliances.sewing...|
# |2232732135054115162|    apparel.trousers|
# |2232732122924187694|construction.tool...|
# |2090228413380952337|   apparel.underwear|
# |2053013561982059281|     apparel.costume|
# |2084962304016777941|     apparel.costume|
# |2232732104888681081|       apparel.scarf|
# |2232732107312988837|      apparel.shorts|
# |2053013562451821351|     apparel.costume|
# |2232732134441746764|      apparel.tshirt|
# |2053013553694114093|       apparel.glove|
# |2232732092297380188|appliances.kitche...|
# +-------------------+--------------------+
# only showing top 20 rows

# %%
filtered_df.filter(filtered_df["product_id"] == 10600074).isnull
# Out:
# 1528

# %%
# Filtrer les lignes où product_id est égal à 10600074
filtered_rows = filtered_df.filter(filtered_df["product_id"] == "22700129")

# Sélectionner les colonnes "category_id", "category_code", et "brand" et afficher les 10 premières lignes
filtered_rows.select("product_id","category_id", "category_code", "brand").show(50, truncate=False)
# Out:
# +----------+-------------------+-------------+-----+
# |product_id|category_id        |category_code|brand|
# +----------+-------------------+-------------+-----+
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# |22700129  |2232732091643068746|NULL         |force|
# +----------+-------------------+-------------+-----+
# only showing top 50 rows

# %%
filtered_df.show(20)
# Out:
# +-------------------+----------+----------+-------------------+--------------------+-------+-------+---------+--------------------+
# |         event_time|event_type|product_id|        category_id|       category_code|  brand|  price|  user_id|        user_session|
# +-------------------+----------+----------+-------------------+--------------------+-------+-------+---------+--------------------+
# |2020-02-26 15:55:17|      view| 100082169|2232732101164139047|appliances.enviro...|   efba|  48.88|581382181|6915e61d-80ad-476...|
# |2020-02-26 15:55:18|      view|   1005017|2232732093077520756|construction.tool...| huawei|  87.44|515230351|78543db1-26b8-454...|
# |2020-02-26 15:55:18|      view|  15100344|2232732107413652135|      apparel.shorts|    bts| 508.87|539960471|4a6305cb-9d30-4bb...|
# |2020-02-26 15:55:18|      view|   1005160|2232732093077520756|construction.tool...| xiaomi| 181.29|547783521|1370d9c0-0904-495...|
filtered_df = filtered_df.filter(filtered_df["category_code"].isNotNull())

# Compter le nombre de lignes après suppression
final_count = filtered_df.count()

# Afficher le nombre de lignes supprimées
print(f"Nombre de lignes supprimées : {initial_count - final_count}")
# Out:
# [Stage 21:==================================================>     (19 + 2) / 21]
# Nombre de lignes supprimées : 6519313

# %%
filtered_df.select("user_id").distinct().count()
# Out:
# 1446961

# %%
filtered_df.select( "category_id", "category_code").distinct().count()
# Out:
# 974

# %%
brand_mapping_df = filtered_df.select("product_id", "brand").distinct().count()

# %%
brand_mapping_df
# Out:
# 283814

# %%
from pyspark.sql.functions import max

# Calculer la valeur maximale de la colonne total_purchase_value
max_value = user_stats_df.agg(max("total_purchase_value").alias("max_total_purchase_value")).collect()[0][0]

# Afficher la valeur maximale
print(f"La valeur maximale de total_purchase_value est : {max_value}")
# Out:
# [Stage 47:=========================================>                (5 + 2) / 7]
# La valeur maximale de total_purchase_value est : 1220342.07

# %%
from pyspark.sql.functions import when, col

# Calculer les quartiles
quartiles = user_stats_df.approxQuantile("total_purchase_value", [0.25, 0.5, 0.75], 0)

q1 = quartiles[0]
q2 = quartiles[1]
q3 = quartiles[2]

# Ajouter une colonne pour classer les acheteurs en fonction de leur total_purchase_value
user_stats_df = user_stats_df.withColumn(
    "buyer_category",
    when(col("total_purchase_value") <= q1, "Faible acheteur")
    .when((col("total_purchase_value") > q1) & (col("total_purchase_value") <= q2), "Acheteur moyen")
    .when((col("total_purchase_value") > q2) & (col("total_purchase_value") <= q3), "Bon acheteur")
    .otherwise("Très bon acheteur")
)



# Afficher quelques lignes pour vérifier
user_stats_df.select("total_purchase_value", "buyer_category").show(10, truncate=False)
# Out:
# +--------------------+-----------------+
# |total_purchase_value|buyer_category   |
# +--------------------+-----------------+
# |1415.62             |Bon acheteur     |
# |3826.11             |Très bon acheteur|
# |3552.11             |Très bon acheteur|
# |463.28              |Acheteur moyen   |
# |891.9               |Bon acheteur     |
# |616.76              |Acheteur moyen   |
# |800.64              |Bon acheteur     |
# |1073.22             |Bon acheteur     |
# |25.68               |Faible acheteur  |
# |1207.52             |Bon acheteur     |
# +--------------------+-----------------+
# only showing top 10 rows

# %%
# 2. Création et chargement des mappings pour `category_code` et `brand`
# Extraire les paires uniques product_id, category_id et category_code
product_category_mapping_df = filtered_df.select( "category_id", "category_code").distinct().cache()
brand_mapping_df = filtered_df.select("product_id", "brand").distinct().cache()
# Out:
# 24/08/23 08:35:24 WARN CacheManager: Asked to cache already cached data.

# %%
product_category_mapping_df.count(), len(product_category_mapping_df.columns)
# Out:
# (974, 2)

# %%
from pyspark.sql.functions import col, sum, isnan, when

# Compter les valeurs NULL dans chaque colonne du DataFrame product_category_mapping_df
null_counts = product_category_mapping_df.select([sum(when(col(c).isNull(), 1).otherwise(0)).alias(c) for c in product_category_mapping_df.columns])

# Afficher le résultat
null_counts.show()
# Out:
# [Stage 80:===============================================>      (177 + 4) / 200]
# +----------+-----------+-------------+
# |product_id|category_id|category_code|
# +----------+-----------+-------------+
# |         0|          0|            0|
# +----------+-----------+-------------+

# %%
# Filtrer les lignes où category_id est égal à 2232732093077520756
filtered_df = product_category_mapping_df.filter(product_category_mapping_df["category_id"] == 2232732093077520756)

# Vérifier si le résultat contient au moins une ligne
exists = filtered_df.count() > 0

# Afficher le résultat
if exists:
    print("La valeur 2232732093077520756 est présente dans la colonne 'category_id'.")
else:
    print("La valeur 2232732093077520756 n'est pas présente dans la colonne 'category_id'.")
# Out:
# [Stage 104:==================================================>  (189 + 4) / 200]
# La valeur 2232732093077520756 est présente dans la colonne 'category_id'.

# %%
brand_mapping_df.distinct().count(), len(brand_mapping_df.columns)
# Out:
# (283814, 2)

# %%
# 2. Création et chargement des mappings pour `category_code` et `brand`
# Extraire les paires uniques product_id, category_id et category_code
product_category_mapping_df = filtered_df.select("product_id", "category_id", "category_code").distinct().cache()
brand_mapping_df = filtered_df.select("product_id", "brand").distinct().cache()

# Sauvegarder ces mappings dans des fichiers Parquet pour une utilisation ultérieure
product_category_mapping_output_path = "/home/jovyan/work/product_category_mapping.parquet"
brand_mapping_output_path = "/home/jovyan/work/brand_mapping.parquet"
product_category_mapping_df.write.mode("overwrite").parquet(product_category_mapping_output_path)
brand_mapping_df.write.mode("overwrite").parquet(brand_mapping_output_path)

# Charger les mappings depuis les fichiers Parquet
product_category_mapping_df = spark.read.parquet(product_category_mapping_output_path).cache()
brand_mapping_df = spark.read.parquet(brand_mapping_output_path).cache()

# Renommer les colonnes dans les DataFrames de mapping pour éviter l'ambiguïté
product_category_mapping_df = product_category_mapping_df.withColumnRenamed("category_code", "mapped_category_code")
brand_mapping_df = brand_mapping_df.withColumnRenamed("brand", "mapped_brand")

# Joindre filtered_df avec product_category_mapping_df et brand_mapping_df pour ajouter les colonnes 'mapped_category_code' et 'mapped_brand'
filtered_df_with_mapping = filtered_df.join(product_category_mapping_df, on="product_id", how="left") \
                                      .join(brand_mapping_df, on="product_id", how="left")

# Remplacer les valeurs NULL dans 'category_code' et 'brand' par les valeurs correspondantes de la jointure
filtered_df = filtered_df_with_mapping.withColumn(
    "category_code",
    coalesce(filtered_df_with_mapping["category_code"], filtered_df_with_mapping["mapped_category_code"])
).withColumn(
    "brand",
    coalesce(filtered_df_with_mapping["brand"], filtered_df_with_mapping["mapped_brand"])
).cache()

# %%
# Nouveau




from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, coalesce, lit, count, countDistinct, avg, sum, max as spark_max, round, dayofweek, hour, row_number, datediff
from pyspark.sql import Window
import pandas as pd

# Initialisation de la session Spark
spark = SparkSession.builder.appName("E-Amazing Data Processing").getOrCreate()

# Définir le chemin des fichiers
output_path = "./data/filtered_df_output.parquet"

# Fonction de lecture du fichier Parquet et conversion de la colonne event_time
def load_and_prepare_data(path):
    df = spark.read.parquet(path).cache()
    return df.withColumn("event_time", col("event_time").cast("timestamp"))

# Fonction d'ajout de colonnes supplémentaires
def add_additional_columns(df):
    df = df.withColumn("event_day_of_week", dayofweek(col("event_time"))) \
           .withColumn("event_hour", hour(col("event_time")))
    return df

# Fonction de calcul des statistiques par utilisateur et période
def compute_user_stats(df, period):
    views = df.filter(col("event_type") == "view").groupBy("user_id").agg(count("*").alias(f"number_of_views_{period}"))
    carts = df.filter(col("event_type") == "cart").groupBy("user_id").agg(count("*").alias(f"number_of_carts_{period}"))
    sessions = df.groupBy("user_id").agg(countDistinct("user_session").alias(f"number_of_sessions_{period}"))
    purchases = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(
        count("*").alias(f"count_products_{period}"),
        round(avg("price"), 2).alias(f"avg_price_{period}")
    )
    return views.join(carts, "user_id").join(sessions, "user_id").join(purchases, "user_id")

# Fonction pour calculer les autres statistiques
def compute_other_stats(df, now):
    last_purchase = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(spark_max("event_time").alias("last_purchase")).cache()
    days_since_last_purchase = last_purchase.withColumn("days_since_last_purchase", datediff(lit(now), col("last_purchase"))).cache()

    total_purchase_value = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(round(sum("price"), 2).alias("total_purchase_value")).cache()
    
    return days_since_last_purchase, total_purchase_value

# Fonction principale de traitement
def main():
    filtered_df = load_and_prepare_data(output_path)
    
    # Ajouter des colonnes supplémentaires
    filtered_df = add_additional_columns(filtered_df)
    
    # Définir les périodes de temps
    now = filtered_df.select(spark_max("event_time")).collect()[0][0]
    last_2_months = now - pd.DateOffset(months=2)
    last_5_months = now - pd.DateOffset(months=5)
    last_7_months = now - pd.DateOffset(months=7)

    # Filtrer les données pour chaque période
    filtered_df_2m = filtered_df.filter(col("event_time") >= lit(last_2_months)).cache()
    filtered_df_5m = filtered_df.filter(col("event_time") >= lit(last_5_months)).cache()
    filtered_df_7m = filtered_df.filter(col("event_time") >= lit(last_7_months)).cache()

    # Calculer les statistiques pour chaque période
    stats_2m = compute_user_stats(filtered_df_2m, "2m").cache()
    stats_5m = compute_user_stats(filtered_df_5m, "5m").cache()
    stats_7m = compute_user_stats(filtered_df_7m, "7m").cache()

    # Union des statistiques pour les différentes périodes
    stats_all = stats_2m.join(stats_5m, "user_id").join(stats_7m, "user_id").cache()

    # Calculer les autres statistiques
    days_since_last_purchase, total_purchase_value = compute_other_stats(filtered_df, now)
    
    # Finaliser et combiner les résultats
    user_stats_df = stats_all.join(days_since_last_purchase, "user_id") \
                             .join(total_purchase_value, "user_id")
    
    # Calcul des quartiles pour la colonne total_purchase_value
    quartiles = user_stats_df.approxQuantile("total_purchase_value", [0.25, 0.5, 0.75], 0)
    
    q1 = quartiles[0]
    q2 = quartiles[1]
    q3 = quartiles[2]

    # Remplacer la segmentation par la catégorisation des acheteurs en fonction des quartiles
    user_stats_df = user_stats_df.withColumn(
        "buyer_category",
        when(col("total_purchase_value") <= q1, "Faible acheteur")
        .when((col("total_purchase_value") > q1) & (col("total_purchase_value") <= q2), "Acheteur moyen")
        .when((col("total_purchase_value") > q2) & (col("total_purchase_value") <= q3), "Bon acheteur")
        .otherwise("Très bon acheteur")
    ).cache()

    # Affichage du DataFrame final
    user_stats_df.show()

# Exécuter le script principal
if __name__ == "__main__":
    main()
# Out:
# 24/08/23 09:12:19 WARN MemoryStore: Not enough space to cache rdd_236_6 in memory! (computed 25.5 MiB so far)
# 24/08/23 09:12:19 WARN BlockManager: Persisting block rdd_236_6 to disk instead.
# 24/08/23 09:12:29 WARN MemoryStore: Not enough space to cache rdd_236_4 in memory! (computed 44.2 MiB so far)
# 24/08/23 09:12:29 WARN BlockManager: Persisting block rdd_236_4 to disk instead.
# 24/08/23 09:12:29 WARN MemoryStore: Not enough space to cache rdd_236_5 in memory! (computed 43.9 MiB so far)
# 24/08/23 09:12:29 WARN BlockManager: Persisting block rdd_236_5 to disk instead.
# 24/08/23 09:12:51 WARN MemoryStore: Not enough space to cache rdd_236_4 in memory! (computed 25.5 MiB so far)
# 24/08/23 09:12:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_236_5 in memory.
# 24/08/23 09:12:51 WARN MemoryStore: Not enough space to cache rdd_236_5 in memory! (computed 384.0 B so far)
# 24/08/23 09:12:51 WARN MemoryStore: Not enough space to cache rdd_236_6 in memory! (computed 13.0 MiB so far)
# 24/08/23 09:12:59 WARN MemoryStore: Not enough space to cache rdd_236_8 in memory! (computed 12.6 MiB so far)
# 24/08/23 09:12:59 WARN BlockManager: Persisting block rdd_236_8 to disk instead.
# 24/08/23 09:13:00 WARN MemoryStore: Not enough space to cache rdd_236_10 in memory! (computed 12.5 MiB so far)
# 24/08/23 09:13:00 WARN BlockManager: Persisting block rdd_236_10 to disk instead.
# 24/08/23 09:13:09 WARN MemoryStore: Not enough space to cache rdd_236_9 in memory! (computed 24.9 MiB so far)
# 24/08/23 09:13:09 WARN BlockManager: Persisting block rdd_236_9 to disk instead.
# 24/08/23 09:13:26 WARN MemoryStore: Not enough space to cache rdd_236_11 in memory! (computed 43.2 MiB so far)
# 24/08/23 09:13:26 WARN BlockManager: Persisting block rdd_236_11 to disk instead.
# 24/08/23 09:13:43 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_236_9 in memory.
# 24/08/23 09:13:43 WARN MemoryStore: Not enough space to cache rdd_236_9 in memory! (computed 384.0 B so far)
# 24/08/23 09:13:43 WARN MemoryStore: Not enough space to cache rdd_236_8 in memory! (computed 43.3 MiB so far)
# 24/08/23 09:13:43 WARN MemoryStore: Not enough space to cache rdd_236_10 in memory! (computed 31.0 MiB so far)
# 24/08/23 09:13:46 WARN MemoryStore: Not enough space to cache rdd_236_11 in memory! (computed 43.2 MiB so far)
# 24/08/23 09:13:50 WARN MemoryStore: Not enough space to cache rdd_236_13 in memory! (computed 12.4 MiB so far)
# 24/08/23 09:13:50 WARN BlockManager: Persisting block rdd_236_13 to disk instead.
# 24/08/23 09:13:51 WARN MemoryStore: Not enough space to cache rdd_236_14 in memory! (computed 12.6 MiB so far)
# 24/08/23 09:13:51 WARN BlockManager: Persisting block rdd_236_14 to disk instead.
# 24/08/23 09:13:57 WARN MemoryStore: Not enough space to cache rdd_236_12 in memory! (computed 24.7 MiB so far)
# 24/08/23 09:13:57 WARN BlockManager: Persisting block rdd_236_12 to disk instead.
# 24/08/23 09:14:08 WARN MemoryStore: Not enough space to cache rdd_236_15 in memory! (computed 41.8 MiB so far)
# 24/08/23 09:14:08 WARN BlockManager: Persisting block rdd_236_15 to disk instead.
# 24/08/23 09:14:24 WARN MemoryStore: Not enough space to cache rdd_236_14 in memory! (computed 12.6 MiB so far)
# 24/08/23 09:14:24 WARN MemoryStore: Not enough space to cache rdd_236_13 in memory! (computed 42.5 MiB so far)
# 24/08/23 09:14:27 WARN MemoryStore: Not enough space to cache rdd_236_12 in memory! (computed 42.8 MiB so far)
# 24/08/23 09:14:28 WARN MemoryStore: Not enough space to cache rdd_236_15 in memory! (computed 41.8 MiB so far)
# 24/08/23 09:14:34 WARN MemoryStore: Not enough space to cache rdd_236_17 in memory! (computed 12.0 MiB so far)
# 24/08/23 09:14:34 WARN BlockManager: Persisting block rdd_236_17 to disk instead.
# 24/08/23 09:14:37 WARN MemoryStore: Not enough space to cache rdd_236_19 in memory! (computed 11.8 MiB so far)
# 24/08/23 09:14:37 WARN BlockManager: Persisting block rdd_236_19 to disk instead.
# 24/08/23 09:14:43 WARN MemoryStore: Not enough space to cache rdd_236_16 in memory! (computed 24.0 MiB so far)
# 24/08/23 09:14:43 WARN BlockManager: Persisting block rdd_236_16 to disk instead.
# 24/08/23 09:15:01 WARN MemoryStore: Not enough space to cache rdd_236_18 in memory! (computed 41.0 MiB so far)
# 24/08/23 09:15:01 WARN BlockManager: Persisting block rdd_236_18 to disk instead.
# 24/08/23 09:15:21 WARN MemoryStore: Not enough space to cache rdd_236_16 in memory! (computed 24.0 MiB so far)
# 24/08/23 09:15:21 WARN MemoryStore: Not enough space to cache rdd_236_18 in memory! (computed 12.0 MiB so far)
# 24/08/23 09:15:21 WARN MemoryStore: Not enough space to cache rdd_236_17 in memory! (computed 41.5 MiB so far)
# 24/08/23 09:15:23 WARN MemoryStore: Not enough space to cache rdd_236_19 in memory! (computed 40.3 MiB so far)
# 24/08/23 09:15:32 WARN MemoryStore: Not enough space to cache rdd_236_20 in memory! (computed 38.3 MiB so far)
# 24/08/23 09:15:32 WARN BlockManager: Persisting block rdd_236_20 to disk instead.
# 24/08/23 09:15:35 WARN MemoryStore: Not enough space to cache rdd_236_20 in memory! (computed 38.3 MiB so far)
# 24/08/23 09:15:35 WARN MemoryStore: Not enough space to cache rdd_236_4 in memory! (computed 12.7 MiB so far)
# 24/08/23 09:15:35 WARN MemoryStore: Not enough space to cache rdd_236_6 in memory! (computed 13.0 MiB so far)
# 24/08/23 09:15:35 WARN MemoryStore: Not enough space to cache rdd_236_5 in memory! (computed 25.1 MiB so far)
# 24/08/23 09:15:36 WARN MemoryStore: Not enough space to cache rdd_236_8 in memory! (computed 12.6 MiB so far)
# 24/08/23 09:15:36 WARN MemoryStore: Not enough space to cache rdd_236_11 in memory! (computed 6.5 MiB so far)
# 24/08/23 09:15:36 WARN MemoryStore: Not enough space to cache rdd_236_10 in memory! (computed 18.7 MiB so far)
# 24/08/23 09:15:36 WARN MemoryStore: Not enough space to cache rdd_236_9 in memory! (computed 12.5 MiB so far)
# 24/08/23 09:15:36 WARN MemoryStore: Not enough space to cache rdd_236_14 in memory! (computed 6.5 MiB so far)
# 24/08/23 09:15:36 WARN MemoryStore: Not enough space to cache rdd_236_15 in memory! (computed 6.3 MiB so far)
# 24/08/23 09:15:36 WARN MemoryStore: Not enough space to cache rdd_236_13 in memory! (computed 6.5 MiB so far)
# 24/08/23 09:15:37 WARN MemoryStore: Not enough space to cache rdd_236_12 in memory! (computed 42.8 MiB so far)
# 24/08/23 09:15:37 WARN MemoryStore: Not enough space to cache rdd_236_18 in memory! (computed 12.0 MiB so far)
# 24/08/23 09:15:37 WARN MemoryStore: Not enough space to cache rdd_236_19 in memory! (computed 6.1 MiB so far)
# 24/08/23 09:15:37 WARN MemoryStore: Not enough space to cache rdd_236_16 in memory! (computed 24.0 MiB so far)
# 24/08/23 09:15:37 WARN MemoryStore: Not enough space to cache rdd_236_17 in memory! (computed 23.7 MiB so far)
# 24/08/23 09:15:38 WARN MemoryStore: Not enough space to cache rdd_236_20 in memory! (computed 38.3 MiB so far)
# 24/08/23 09:15:45 WARN MemoryStore: Not enough space to cache rdd_236_4 in memory! (computed 25.5 MiB so far)
# 24/08/23 09:15:45 WARN MemoryStore: Not enough space to cache rdd_236_6 in memory! (computed 6.6 MiB so far)
# 24/08/23 09:15:45 WARN MemoryStore: Not enough space to cache rdd_236_5 in memory! (computed 12.9 MiB so far)
# 24/08/23 09:15:48 WARN MemoryStore: Not enough space to cache rdd_236_8 in memory! (computed 24.8 MiB so far)
# 24/08/23 09:15:52 WARN MemoryStore: Not enough space to cache rdd_236_10 in memory! (computed 31.0 MiB so far)
# 24/08/23 09:15:53 WARN MemoryStore: Not enough space to cache rdd_236_12 in memory! (computed 6.5 MiB so far)
# 24/08/23 09:15:56 WARN MemoryStore: Not enough space to cache rdd_236_11 in memory! (computed 67.2 MiB so far)
# 24/08/23 09:16:04 WARN MemoryStore: Not enough space to cache rdd_236_14 in memory! (computed 66.1 MiB so far)
# 24/08/23 09:16:08 WARN MemoryStore: Not enough space to cache rdd_236_15 in memory! (computed 41.8 MiB so far)
# 24/08/23 09:16:11 WARN MemoryStore: Not enough space to cache rdd_236_16 in memory! (computed 65.1 MiB so far)
# 24/08/23 09:16:43 WARN MemoryStore: Not enough space to cache rdd_236_18 in memory! (computed 64.1 MiB so far)
# 24/08/23 09:16:56 WARN MemoryStore: Not enough space to cache rdd_236_19 in memory! (computed 63.0 MiB so far)
# 24/08/23 09:17:21 WARN MemoryStore: Not enough space to cache rdd_250_19 in memory! (computed 23.4 MiB so far)
# 24/08/23 09:17:21 WARN BlockManager: Persisting block rdd_250_19 to disk instead.
# 24/08/23 09:17:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_250_10 in memory.
# 24/08/23 09:17:24 WARN MemoryStore: Not enough space to cache rdd_250_10 in memory! (computed 384.0 B so far)
# 24/08/23 09:17:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_250_11 in memory.
# 24/08/23 09:17:24 WARN MemoryStore: Not enough space to cache rdd_250_11 in memory! (computed 384.0 B so far)
# 24/08/23 09:17:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_250_12 in memory.
# 24/08/23 09:17:24 WARN MemoryStore: Not enough space to cache rdd_250_12 in memory! (computed 384.0 B so far)
# 24/08/23 09:17:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_250_13 in memory.
# 24/08/23 09:17:24 WARN MemoryStore: Not enough space to cache rdd_250_13 in memory! (computed 384.0 B so far)
# 24/08/23 09:17:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_250_14 in memory.
# 24/08/23 09:17:24 WARN MemoryStore: Not enough space to cache rdd_250_14 in memory! (computed 384.0 B so far)
# 24/08/23 09:17:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_250_15 in memory.
# 24/08/23 09:17:24 WARN MemoryStore: Not enough space to cache rdd_250_15 in memory! (computed 384.0 B so far)
# 24/08/23 09:17:28 WARN MemoryStore: Not enough space to cache rdd_250_18 in memory! (computed 41.1 MiB so far)
# 24/08/23 09:17:28 WARN BlockManager: Persisting block rdd_250_18 to disk instead.
# 24/08/23 09:17:40 WARN MemoryStore: Not enough space to cache rdd_250_15 in memory! (computed 24.1 MiB so far)
# 24/08/23 09:17:40 WARN MemoryStore: Not enough space to cache rdd_250_15 in memory! (computed 24.1 MiB so far)
# 24/08/23 09:17:49 WARN MemoryStore: Not enough space to cache rdd_250_18 in memory! (computed 64.1 MiB so far)
# 24/08/23 09:17:50 WARN MemoryStore: Not enough space to cache rdd_250_18 in memory! (computed 64.1 MiB so far)
# 24/08/23 09:17:50 WARN MemoryStore: Not enough space to cache rdd_250_18 in memory! (computed 64.1 MiB so far)
# 24/08/23 09:17:51 WARN MemoryStore: Not enough space to cache rdd_250_18 in memory! (computed 64.1 MiB so far)
# 24/08/23 09:17:55 WARN MemoryStore: Not enough space to cache rdd_250_18 in memory! (computed 12.0 MiB so far)
# 24/08/23 09:18:05 WARN MemoryStore: Not enough space to cache rdd_250_18 in memory! (computed 41.1 MiB so far)
# 24/08/23 09:18:05 WARN MemoryStore: Not enough space to cache rdd_250_19 in memory! (computed 11.8 MiB so far)
# 24/08/23 09:18:12 WARN MemoryStore: Not enough space to cache rdd_250_18 in memory! (computed 41.1 MiB so far)
# 24/08/23 09:18:12 WARN MemoryStore: Not enough space to cache rdd_250_19 in memory! (computed 40.3 MiB so far)
# 24/08/23 09:18:17 WARN MemoryStore: Not enough space to cache rdd_250_18 in memory! (computed 64.1 MiB so far)
# 24/08/23 09:18:17 WARN MemoryStore: Not enough space to cache rdd_250_19 in memory! (computed 23.4 MiB so far)
# 24/08/23 09:18:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:22 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:18:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/08/23 09:19:05 WARN MemoryStore: Not enough space to cache rdd_293_0 in memory! (computed 26.5 MiB so far)
# 24/08/23 09:19:05 WARN BlockManager: Persisting block rdd_293_0 to disk instead.
# 24/08/23 09:19:05 WARN MemoryStore: Not enough space to cache rdd_293_2 in memory! (computed 25.6 MiB so far)
# 24/08/23 09:19:05 WARN BlockManager: Persisting block rdd_293_2 to disk instead.
# 24/08/23 09:19:17 WARN MemoryStore: Not enough space to cache rdd_236_4 in memory! (computed 69.1 MiB so far)
# 24/08/23 09:19:34 WARN MemoryStore: Not enough space to cache rdd_236_6 in memory! (computed 68.8 MiB so far)
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/lib/python3.9/dist-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/usr/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 102
#     100 # Exécuter le script principal
#     101 if __name__ == "__main__":
# --> 102     main()
#
# Cell In[44], line 82, in main()
#      78 user_stats_df = stats_all.join(days_since_last_purchase, "user_id") \
#      79                          .join(total_purchase_value, "user_id")
#      81 # Calcul des quartiles pour la colonne total_purchase_value
# ---> 82 quartiles = user_stats_df.approxQuantile("total_purchase_value", [0.25, 0.5, 0.75], 0)
#      84 q1 = quartiles[0]
#      85 q2 = quartiles[1]
#
# File /usr/local/lib/python3.9/dist-packages/pyspark/sql/dataframe.py:4847, in DataFrame.approxQuantile(self, col, probabilities, relativeError)
#    4838     raise PySparkValueError(
#    4839         error_class="NEGATIVE_VALUE",
#    4840         message_parameters={
#    (...)
#    4843         },
#    4844     )
#    4845 relativeError = float(relativeError)
# -> 4847 jaq = self._jdf.stat().approxQuantile(col, probabilities, relativeError)
#    4848 jaq_list = [list(j) for j in jaq]
#    4849 return jaq_list[0] if isStr else jaq_list
#
# File /usr/local/lib/python3.9/dist-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File /usr/local/lib/python3.9/dist-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File /usr/local/lib/python3.9/dist-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /usr/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:
# [Stage 131:> (6 + 4) / 21][Stage 132:> (0 + 0) / 21][Stage 133:> (0 + 0) / 21]

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, lit, count, countDistinct, avg, sum, max as spark_max, round, dayofweek, hour, row_number, datediff
from pyspark.sql import Window
from pyspark import StorageLevel
import pandas as pd

# Initialisation de la session Spark avec des configurations optimisées
spark = SparkSession.builder \
    .appName("E-Amazing Data Processing") \
    .config("spark.driver.memory", "2g") \
    .config("spark.memory.fraction", "0.6") \
    .getOrCreate()

# Définir le chemin des fichiers

output_path = "./data/filtered_df_output.parquet"

# Fonction de lecture du fichier Parquet et conversion de la colonne event_time
def load_and_prepare_data(path):
    df = spark.read.parquet(path)
    return df.withColumn("event_time", col("event_time").cast("timestamp"))

# Fonction d'ajout de colonnes supplémentaires
def add_additional_columns(df):
    return df.withColumn("event_day_of_week", dayofweek(col("event_time"))) \
             .withColumn("event_hour", hour(col("event_time")))

# Fonction de calcul des statistiques par utilisateur et période
def compute_user_stats(df, period):
    views = df.filter(col("event_type") == "view").groupBy("user_id").agg(count("*").alias(f"number_of_views_{period}"))
    carts = df.filter(col("event_type") == "cart").groupBy("user_id").agg(count("*").alias(f"number_of_carts_{period}"))
    sessions = df.groupBy("user_id").agg(countDistinct("user_session").alias(f"number_of_sessions_{period}"))
    purchases = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(
        count("*").alias(f"count_products_{period}"),
        round(avg("price"), 2).alias(f"avg_price_{period}")
    )
    return views.join(carts, "user_id").join(sessions, "user_id").join(purchases, "user_id")

# Fonction pour calculer les autres statistiques
def compute_other_stats(df, now):
    last_purchase = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(spark_max("event_time").alias("last_purchase"))
    days_since_last_purchase = last_purchase.withColumn("days_since_last_purchase", datediff(lit(now), col("last_purchase")))

    total_purchase_value = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(round(sum("price"), 2).alias("total_purchase_value"))
    
    return days_since_last_purchase, total_purchase_value

# Fonction principale de traitement
def main():
    # Chargement et préparation des données
    filtered_df = load_and_prepare_data(output_path)
    
    # Ajout de colonnes supplémentaires
    filtered_df = add_additional_columns(filtered_df)

    # Définir les périodes de temps
    now = filtered_df.select(spark_max("event_time")).collect()[0][0]
    last_2_months = now - pd.DateOffset(months=2)
    last_5_months = now - pd.DateOffset(months=5)
    last_7_months = now - pd.DateOffset(months=7)

    # Filtrer les données pour chaque période
    filtered_df_2m = filtered_df.filter(col("event_time") >= lit(last_2_months))
    filtered_df_5m = filtered_df.filter(col("event_time") >= lit(last_5_months))
    filtered_df_7m = filtered_df.filter(col("event_time") >= lit(last_7_months))

    # Calculer les statistiques pour chaque période
    stats_2m = compute_user_stats(filtered_df_2m, "2m")
    stats_5m = compute_user_stats(filtered_df_5m, "5m")
    stats_7m = compute_user_stats(filtered_df_7m, "7m")

    # Union des statistiques pour les différentes périodes
    stats_all = stats_2m.join(stats_5m, "user_id").join(stats_7m, "user_id")

    # Calculer les autres statistiques
    days_since_last_purchase, total_purchase_value = compute_other_stats(filtered_df, now)

    # Finaliser et combiner les résultats
    user_stats_df = stats_all.join(days_since_last_purchase, "user_id") \
                             .join(total_purchase_value, "user_id")
    
    # Calcul des quartiles pour la colonne total_purchase_value
    quartiles = user_stats_df.approxQuantile("total_purchase_value", [0.25, 0.5, 0.75], 0)
    
    q1 = quartiles[0]
    q2 = quartiles[1]
    q3 = quartiles[2]

    # Catégorisation des acheteurs en fonction des quartiles
    user_stats_df = user_stats_df.withColumn(
        "buyer_category",
        when(col("total_purchase_value") <= q1, "Faible acheteur")
        .when((col("total_purchase_value") > q1) & (col("total_purchase_value") <= q2), "Acheteur moyen")
        .when((col("total_purchase_value") > q2) & (col("total_purchase_value") <= q3), "Bon acheteur")
        .otherwise("Très bon acheteur")
    )

    # Affichage du DataFrame final
   # user_stats_df.show()
# Compter le nombre de lignes et de colonnes dans user_stats_df
    user_stats_df.schema()

# Afficher les résultats
    print(f"Nombre de lignes : {num_rows}")
    print(f"Nombre de colonnes : {num_columns}")

# Exécuter le script principal
if __name__ == "__main__":
     main()
# Out:
# [Stage 320:==================================>                      (3 + 2) / 5]
# Nombre de lignes : 84864
# Nombre de colonnes : 20

# %%
user_stats_df = spark.read.parquet("./data/user_stats_df_output.parquet")

# %%
user_stats_df.count()
# Out:
# 84864

# %%
user_stats_df.schema
# Out:
# StructType([StructField('user_id', IntegerType(), True), StructField('number_of_views_2m', LongType(), True), StructField('number_of_views_5m', LongType(), True), StructField('number_of_views_7m', LongType(), True), StructField('number_of_carts_2m', LongType(), True), StructField('number_of_carts_5m', LongType(), True), StructField('number_of_carts_7m', LongType(), True), StructField('number_of_sessions_2m', LongType(), True), StructField('number_of_sessions_5m', LongType(), True), StructField('number_of_sessions_7m', LongType(), True), StructField('count_products_2m', LongType(), True), StructField('count_products_5m', LongType(), True), StructField('count_products_7m', LongType(), True), StructField('avg_price_2m', DoubleType(), True), StructField('avg_price_5m', DoubleType(), True), StructField('avg_price_7m', DoubleType(), True), StructField('total_purchase_value', DoubleType(), True), StructField('days_since_last_purchase', IntegerType(), True), StructField('cart_abandonments', LongType(), True), StructField('brand_loyalty', DoubleType(), True), StructField('preferred_brand', StringType(), True), StructField('preferred_category', StringType(), True), StructField('avg_session_duration', DoubleType(), True), StructField('most_active_day', IntegerType(), True), StructField('most_active_time', StringType(), True), StructField('user_segment', StringType(), True)])

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, lit, count, countDistinct, avg, sum, max as spark_max, round, dayofweek, hour, row_number, datediff
from pyspark.sql import Window
from pyspark import StorageLevel
import pandas as pd

# Initialisation de la session Spark
spark = SparkSession.builder \
    .appName("E-Amazing Data Processing") \
    .config("spark.driver.memory", "2g") \
    .config("spark.memory.fraction", "0.6") \
    .getOrCreate()

# Définir le chemin des fichiers
output_path = "./data/filtered_df_output.parquet"

# Fonction de lecture du fichier Parquet et conversion de la colonne event_time
def load_and_prepare_data(path):
    df = spark.read.parquet(path)
    return df.withColumn("event_time", col("event_time").cast("timestamp"))

# Fonction d'ajout de colonnes supplémentaires
def add_additional_columns(df):
    return df.withColumn("event_day_of_week", dayofweek(col("event_time"))) \
             .withColumn("event_hour", hour(col("event_time")))

# Fonction de calcul des statistiques par utilisateur et période
def compute_user_stats(df, period):
    views = df.filter(col("event_type") == "view").groupBy("user_id").agg(count("*").alias(f"number_of_views_{period}"))
    carts = df.filter(col("event_type") == "cart").groupBy("user_id").agg(count("*").alias(f"number_of_carts_{period}"))
    sessions = df.groupBy("user_id").agg(countDistinct("user_session").alias(f"number_of_sessions_{period}"))
    purchases = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(
        count("*").alias(f"count_products_{period}"),
        round(avg("price"), 2).alias(f"avg_price_{period}")
    )
    return views.join(carts, "user_id").join(sessions, "user_id").join(purchases, "user_id")

# Fonction pour calculer les autres statistiques
def compute_other_stats(df, now):
    last_purchase = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(spark_max("event_time").alias("last_purchase"))
    days_since_last_purchase = last_purchase.withColumn("days_since_last_purchase", datediff(lit(now), col("last_purchase")))

    total_purchase_value = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(round(sum("price"), 2).alias("total_purchase_value"))

    # Calcul de la fidélité à une marque (brand loyalty)
    total_purchases_by_user = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(count("*").alias("total_purchases"))
    brand_purchases_by_user = df.filter(col("event_type") == "purchase").groupBy("user_id", "brand").agg(count("*").alias("brand_purchases"))

    window_spec = Window.partitionBy("user_id").orderBy(col("brand_purchases").desc())
    most_purchased_brand = brand_purchases_by_user.withColumn("rank", row_number().over(window_spec)).filter(col("rank") == 1).drop("rank")

    brand_loyalty = most_purchased_brand.join(total_purchases_by_user, "user_id").withColumn("brand_loyalty", round(col("brand_purchases") / col("total_purchases"), 2))

    # Calcul des abandons de panier (cart abandonments)
    cart_events = df.filter(col("event_type") == "cart").groupBy("user_id").agg(count("*").alias("cart_count"))
    purchase_events = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(count("*").alias("purchase_count"))

    cart_abandonments = cart_events.join(purchase_events, "user_id", "left") \
                                   .withColumn("cart_abandonments", when(col("cart_count") > col("purchase_count"), col("cart_count") - col("purchase_count")).otherwise(0)) \
                                   .select("user_id", "cart_abandonments")

    return days_since_last_purchase, total_purchase_value, brand_loyalty, cart_abandonments

# Fonction pour déterminer les préférences (marque et catégorie) et le moment d'activité
def compute_user_preferences_and_activity(df):
    # Déterminer la marque la plus achetée par chaque utilisateur (preferred_brand)
    window_spec_brand = Window.partitionBy("user_id").orderBy(col("brand_purchases").desc())
    most_purchased_brand = df.filter(col("event_type") == "purchase").groupBy("user_id", "brand").agg(count("*").alias("brand_purchases")) \
                             .withColumn("rank", row_number().over(window_spec_brand)).filter(col("rank") == 1).drop("rank").select("user_id", col("brand").alias("preferred_brand"))

    # Déterminer la catégorie la plus achetée par chaque utilisateur (preferred_category)
    window_spec_category = Window.partitionBy("user_id").orderBy(col("category_purchases").desc())
    most_purchased_category = df.filter(col("event_type") == "purchase").groupBy("user_id", "category_code").agg(count("*").alias("category_purchases")) \
                                .withColumn("rank", row_number().over(window_spec_category)).filter(col("rank") == 1).drop("rank").select("user_id", col("category_code").alias("preferred_category"))

    # Calcul du moment d'activité le plus fréquent (most_active_time)
    most_active_time = df.withColumn("time_of_day",
        when(col("event_hour").between(5, 12), "morning")
        .when(col("event_hour").between(12, 17), "afternoon")
        .otherwise("evening")
    ).groupBy("user_id", "time_of_day").agg(count("*").alias("time_activity")) \
      .withColumn("rank", row_number().over(Window.partitionBy("user_id").orderBy(col("time_activity").desc()))) \
      .filter(col("rank") == 1).drop("rank").select("user_id", col("time_of_day").alias("most_active_time"))

    # Calcul du jour le plus actif (most_active_day)
    most_active_day = df.groupBy("user_id", "event_day_of_week")\
                        .agg(count("*").alias("day_activity")) \
                        .withColumn("rank", row_number().over(Window.partitionBy("user_id").orderBy(col("day_activity").desc()))) \
                        .filter(col("rank") == 1).drop("rank")\
                        .select("user_id", col("event_day_of_week").alias("most_active_day"))



    # Mapping des jours de la semaine
    most_active_day = most_active_day.withColumn(
        "most_active_day",
        when(col("most_active_day") == 1, "dimanche")
        .when(col("most_active_day") == 2, "lundi")
        .when(col("most_active_day") == 3, "mardi")
        .when(col("most_active_day") == 4, "mercredi")
        .when(col("most_active_day") == 5, "jeudi")
        .when(col("most_active_day") == 6, "vendredi")
        .when(col("most_active_day") == 7, "samedi")
        )
    
    return most_purchased_brand, most_purchased_category, most_active_time, most_active_day

# Fonction principale de traitement
def main():
    # Chargement et préparation des données
    filtered_df = load_and_prepare_data(output_path)
    
    # Ajout de colonnes supplémentaires
    filtered_df = add_additional_columns(filtered_df)

    # Définir les périodes de temps
    now = filtered_df.select(spark_max("event_time")).collect()[0][0]
    last_2_months = now - pd.DateOffset(months=2)
    last_5_months = now - pd.DateOffset(months=5)
    last_7_months = now - pd.DateOffset(months=7)

    # Filtrer les données pour chaque période
    filtered_df_2m = filtered_df.filter(col("event_time") >= lit(last_2_months))
    filtered_df_5m = filtered_df.filter(col("event_time") >= lit(last_5_months))
    filtered_df_7m = filtered_df.filter(col("event_time") >= lit(last_7_months))

    # Calculer les statistiques pour chaque période
    stats_2m = compute_user_stats(filtered_df_2m, "2m")
    stats_5m = compute_user_stats(filtered_df_5m, "5m")
    stats_7m = compute_user_stats(filtered_df_7m, "7m")

    # Union des statistiques pour les différentes périodes
    stats_all = stats_2m.join(stats_5m, "user_id").join(stats_7m, "user_id")

    # Calculer les autres statistiques
    days_since_last_purchase, total_purchase_value, brand_loyalty, cart_abandonments = compute_other_stats(filtered_df, now)

    # Calculer les préférences (marque, catégorie) et les moments d'activité
    preferred_brand, preferred_category, most_active_time, most_active_day = compute_user_preferences_and_activity(filtered_df)

    # Finaliser et combiner les résultats
    user_stats_df = stats_all.join(days_since_last_purchase, "user_id") \
                             .join(total_purchase_value, "user_id") \
                             .join(brand_loyalty, "user_id", "left") \
                             .join(cart_abandonments, "user_id", "left") \
                             .join(preferred_brand, "user_id", "left") \
                             .join(preferred_category, "user_id", "left") \
                             .join(most_active_time, "user_id", "left") \
                             .join(most_active_day, "user_id", "left")

    

  

    # Affichage du DataFrame final
    user_stats_df.show()

# Exécuter le script principal
if __name__ == "__main__":
    main()
# Out:
# 24/09/01 16:49:29 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# [Stage 147:>                                                        (0 + 1) / 1]
# +---------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+-------------------+------------------------+--------------------+--------+---------------+---------------+-------------+-----------------+---------------+--------------------+----------------+---------------+
# |  user_id|number_of_views_2m|number_of_carts_2m|number_of_sessions_2m|count_products_2m|avg_price_2m|number_of_views_5m|number_of_carts_5m|number_of_sessions_5m|count_products_5m|avg_price_5m|number_of_views_7m|number_of_carts_7m|number_of_sessions_7m|count_products_7m|avg_price_7m|      last_purchase|days_since_last_purchase|total_purchase_value|   brand|brand_purchases|total_purchases|brand_loyalty|cart_abandonments|preferred_brand|  preferred_category|most_active_time|most_active_day|
# +---------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+-------------------+------------------------+--------------------+--------+---------------+---------------+-------------+-----------------+---------------+--------------------+----------------+---------------+
# |359242441|                75|                 4|                    9|                1|       56.63|                75|                 4|                    9|                1|       56.63|                75|                 4|                    9|                1|       56.63|2020-04-11 08:08:14|                      19|               56.63| tp-link|              1|              1|          1.0|                3|        tp-link|furniture.kitchen...|         morning|       vendredi|
# |438263431|               138|                 4|                   46|                3|        81.7|               324|                 5|                  123|                4|      173.74|               331|                 5|                  128|                4|      173.74|2020-04-19 18:41:51|                      11|              694.95|aerocool|              1|              4|         0.25|                1|       aerocool|                NULL|         evening|         samedi|
# |469107971|                 2|                 1|                    1|                1|       229.5|                 2|                 1|                    1|                1|       229.5|                 2|                 1|                    1|                1|       229.5|2020-04-25 13:48:42|                       5|               229.5|    NULL|              1|              1|          1.0|                0|           NULL|                NULL|       afternoon|         samedi|
# |512368481|                46|                10|                   16|                3|     1400.27|                82|                10|                   30|                3|     1400.27|                96|                11|                   35|                4|     1090.18|2020-03-04 17:37:11|                      57|             4360.72|    asus|              3|              4|         0.75|                7|           asus|electronics.audio...|         morning|          lundi|
# |512369671|                98|                 4|                   13|                2|        8.77|                98|                 4|                   13|                2|        8.77|               104|                 4|                   14|                2|        8.77|2020-04-22 17:59:02|                       8|               17.54|  canyon|              1|              2|          0.5|                2|         canyon|furniture.kitchen...|       afternoon|       mercredi|
# |512371641|                27|                 2|                    8|                1|     1749.85|                37|                 2|                   15|                1|     1749.85|                51|                 3|                   23|                2|       926.4|2020-04-29 17:14:31|                       1|             1852.79|   apple|              1|              2|          0.5|                1|          apple|construction.tool...|         evening|       mercredi|
# |512372691|                24|                 9|                    8|                8|      130.12|                63|                16|                   15|               15|      170.65|                85|                21|                   21|               20|      156.87|2020-04-27 14:34:00|                       3|             3137.49| samsung|              7|             20|         0.35|                1|        samsung|                NULL|         morning|       dimanche|
# +---------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+-------------------+------------------------+--------------------+--------+---------------+---------------+-------------+-----------------+---------------+--------------------+----------------+---------------+
# only showing top 20 rows

# %%
# A partir delà à modifier le code exécution précédente

user_stats_df.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 user_stats_df.show
#
# NameError: name 'user_stats_df' is not defined
# 24/08/29 19:10:59 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 558546 ms exceeds timeout 120000 ms
# 24/08/29 19:11:00 WARN SparkContext: Killing executors is not supported by current scheduler.
# 24/08/29 19:11:00 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:42221
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/29 19:11:00 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:42221
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/29 19:11:01 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:42221
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/29 19:11:01 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:42221
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/29 19:11:01 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:42221
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 24/08/29 19:11:01 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:42221
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 24/08/29 19:11:01 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:42221
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 24/08/29 19:11:01 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:42221
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 24/08/29 19:11:01 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# ...
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/29 19:11:39 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:42221
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/08/29 19:11:39 ERROR Executor: Exit as unable to send heartbeats to driver more than 60 times
# 24/08/29 19:18:45 WARN ShutdownHookManager: ShutdownHook '' timeout, java.util.concurrent.TimeoutException
# java.util.concurrent.TimeoutException
# 	at java.base/java.util.concurrent.FutureTask.get(FutureTask.java:204)
# 	at org.apache.hadoop.util.ShutdownHookManager.executeShutdown(ShutdownHookManager.java:124)
# 	at org.apache.hadoop.util.ShutdownHookManager$1.run(ShutdownHookManager.java:95)
# 24/08/29 19:19:15 WARN ShutdownHookManager: ShutdownHook 'ClientFinalizer' timeout, java.util.concurrent.TimeoutException
# java.util.concurrent.TimeoutException
# 	at java.base/java.util.concurrent.FutureTask.get(FutureTask.java:204)
# 	at org.apache.hadoop.util.ShutdownHookManager.executeShutdown(ShutdownHookManager.java:124)
# 	at org.apache.hadoop.util.ShutdownHookManager$1.run(ShutdownHookManager.java:95)
# 24/08/29 19:19:16 WARN QueuedThreadPool: QueuedThreadPool[SparkUI]@2bde3efe{STOPPING,8<=0<=200,i=6,r=-1,q=0}[NO_TRY] Couldn't stop Thread[SparkUI-36,5,main]
# 24/08/29 19:19:16 WARN QueuedThreadPool: QueuedThreadPool[SparkUI]@2bde3efe{STOPPING,8<=0<=200,i=6,r=-1,q=0}[NO_TRY] Couldn't stop Thread[SparkUI-37,5,main]
# 24/08/29 19:19:16 WARN SparkContext: Ignoring Exception while stopping SparkContext from shutdown hook
# java.lang.InterruptedException
# 	at java.base/java.util.concurrent.locks.AbstractQueuedSynchronizer.tryAcquireSharedNanos(AbstractQueuedSynchronizer.java:1367)
# 	at java.base/java.util.concurrent.CountDownLatch.await(CountDownLatch.java:278)
# 	at org.sparkproject.jetty.server.AbstractConnector.doStop(AbstractConnector.java:373)
# 	at org.sparkproject.jetty.server.AbstractNetworkConnector.doStop(AbstractNetworkConnector.java:88)
# 	at org.sparkproject.jetty.server.ServerConnector.doStop(ServerConnector.java:246)
# 	at org.sparkproject.jetty.util.component.AbstractLifeCycle.stop(AbstractLifeCycle.java:94)
# 	at org.sparkproject.jetty.server.Server.doStop(Server.java:459)
# 	at org.sparkproject.jetty.util.component.AbstractLifeCycle.stop(AbstractLifeCycle.java:94)
# 	at org.apache.spark.ui.ServerInfo.stop(JettyUtils.scala:532)
# 	at org.apache.spark.ui.WebUI.$anonfun$stop$2(WebUI.scala:182)
# 	at org.apache.spark.ui.WebUI.$anonfun$stop$2$adapted(WebUI.scala:182)
# 	at scala.Option.foreach(Option.scala:407)
# 	at org.apache.spark.ui.WebUI.stop(WebUI.scala:182)
# 	at org.apache.spark.ui.SparkUI.stop(SparkUI.scala:157)
# 	at org.apache.spark.SparkContext.$anonfun$stop$7(SparkContext.scala:2248)
# 	at org.apache.spark.SparkContext.$anonfun$stop$7$adapted(SparkContext.scala:2248)
# 	at scala.Option.foreach(Option.scala:407)
# 	at org.apache.spark.SparkContext.$anonfun$stop$6(SparkContext.scala:2248)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.SparkContext.stop(SparkContext.scala:2248)
# 	at org.apache.spark.SparkContext.stop(SparkContext.scala:2211)
# 	at org.apache.spark.SparkContext.$anonfun$new$34(SparkContext.scala:681)
# 	at org.apache.spark.util.SparkShutdownHook.run(ShutdownHookManager.scala:214)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$2(ShutdownHookManager.scala:188)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$1(ShutdownHookManager.scala:188)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.util.SparkShutdownHookManager.runAll(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anon$2.run(ShutdownHookManager.scala:178)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, dayofweek

# Création d'une session Spark
spark = SparkSession.builder.master("local").appName("Test Day of Week").getOrCreate()

# Exemple de DataFrame avec une date
df = spark.createDataFrame([("2020-04-11 08:08:14",)], ["timestamp"])

# Conversion de la colonne en format date et extraction du jour de la semaine
df = df.withColumn("timestamp", col("timestamp").cast("timestamp"))
df = df.withColumn("day_of_week", dayofweek(col("timestamp")))

# Affichage du résultat
df.show()
# Out:
# 24/09/01 16:33:20 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# +-------------------+-----------+
# |          timestamp|day_of_week|
# +-------------------+-----------+
# |2020-04-11 08:08:14|          7|
# +-------------------+-----------+

# %% [markdown]
# A Garder ci-dessous (84864, 24)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, lit, count, countDistinct, avg, sum, max as spark_max, round, dayofweek, hour, row_number, datediff
from pyspark.sql import Window
from pyspark import StorageLevel
import pandas as pd

# Initialisation de la session Spark
spark = SparkSession.builder \
    .appName("E-Amazing Data Processing") \
    .config("spark.driver.memory", "2g") \
    .config("spark.memory.fraction", "0.6") \
    .getOrCreate()

# Définir le chemin des fichiers
output_path = "./data/filtered_df_output.parquet"

# Fonction de lecture du fichier Parquet et conversion de la colonne event_time
def load_and_prepare_data(path):
    df = spark.read.parquet(path)
    return df.withColumn("event_time", col("event_time").cast("timestamp"))

# Fonction d'ajout de colonnes supplémentaires
def add_additional_columns(df):
    return df.withColumn("event_day_of_week", dayofweek(col("event_time"))) \
             .withColumn("event_hour", hour(col("event_time")))

# Fonction de calcul des statistiques par utilisateur et période
def compute_user_stats(df, period):
    views = df.filter(col("event_type") == "view").groupBy("user_id").agg(count("*").alias(f"number_of_views_{period}"))
    carts = df.filter(col("event_type") == "cart").groupBy("user_id").agg(count("*").alias(f"number_of_carts_{period}"))
    sessions = df.groupBy("user_id").agg(countDistinct("user_session").alias(f"number_of_sessions_{period}"))
    purchases = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(
        count("*").alias(f"count_products_{period}"),
        round(avg("price"), 2).alias(f"avg_price_{period}")
    )
    return views.join(carts, "user_id").join(sessions, "user_id").join(purchases, "user_id")

# Fonction pour calculer les autres statistiques
def compute_other_stats(df, now):
    last_purchase = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(spark_max("event_time").alias("last_purchase"))
    days_since_last_purchase = last_purchase.withColumn("days_since_last_purchase", datediff(lit(now), col("last_purchase")))

    total_purchase_value = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(round(sum("price"), 2).alias("total_purchase_value"))

    # Calcul des abandons de panier (cart abandonments)
    cart_events = df.filter(col("event_type") == "cart").groupBy("user_id").agg(count("*").alias("cart_count"))
    purchase_events = df.filter(col("event_type") == "purchase").groupBy("user_id").agg(count("*").alias("purchase_count"))

    cart_abandonments = cart_events.join(purchase_events, "user_id", "left") \
                                   .withColumn("cart_abandonments", when(col("cart_count") > col("purchase_count"), col("cart_count") - col("purchase_count")).otherwise(0)) \
                                   .select("user_id", "cart_abandonments")

    return days_since_last_purchase, total_purchase_value, cart_abandonments

# Fonction pour déterminer les préférences (marque et catégorie) et le moment d'activité
def compute_user_preferences_and_activity(df):
    # Déterminer la marque la plus achetée par chaque utilisateur (preferred_brand)
    window_spec_brand = Window.partitionBy("user_id").orderBy(col("brand_purchases").desc())
    most_purchased_brand = df.filter(col("event_type") == "purchase").groupBy("user_id", "brand").agg(count("*").alias("brand_purchases")) \
                             .withColumn("rank", row_number().over(window_spec_brand)).filter(col("rank") == 1).drop("rank").select("user_id", col("brand").alias("preferred_brand").cast("string"))

    # Déterminer la catégorie la plus achetée par chaque utilisateur (preferred_category)
    window_spec_category = Window.partitionBy("user_id").orderBy(col("category_purchases").desc())
    most_purchased_category = df.filter(col("event_type") == "purchase").groupBy("user_id", "category_code").agg(count("*").alias("category_purchases")) \
                                .withColumn("rank", row_number().over(window_spec_category)).filter(col("rank") == 1).drop("rank").select("user_id", col("category_code").alias("preferred_category").cast("string"))

    # Calcul du moment d'activité le plus fréquent (most_active_time)
    most_active_time = df.withColumn("time_of_day",
        when(col("event_hour").between(5, 12), "morning")
        .when(col("event_hour").between(12, 17), "afternoon")
        .when(col("event_hour").between(18, 23), "evening")
        .otherwise("night")
    )\
    .groupBy("user_id", "time_of_day").agg(count("*").alias("time_activity")) \
    .withColumn("rank", row_number().over(Window.partitionBy("user_id").orderBy(col("time_activity").desc()))) \
    .filter(col("rank") == 1).drop("rank")\
    .select("user_id", col("time_of_day").alias("most_active_time").cast("string")) 

    # Calcul du jour le plus actif (most_active_day)
    most_active_day = df.groupBy("user_id", "event_day_of_week")\
                        .agg(count("*").alias("day_activity")) \
                        .withColumn("rank", row_number().over(Window.partitionBy("user_id").orderBy(col("day_activity").desc()))) \
                        .filter(col("rank") == 1).drop("rank")\
                        .select("user_id", col("event_day_of_week").alias("most_active_day"))

    # Mapping des jours de la semaine
    most_active_day = most_active_day.withColumn(
        "most_active_day",
        when(col("most_active_day") == 1, "dimanche")
        .when(col("most_active_day") == 2, "lundi")
        .when(col("most_active_day") == 3, "mardi")
        .when(col("most_active_day") == 4, "mercredi")
        .when(col("most_active_day") == 5, "jeudi")
        .when(col("most_active_day") == 6, "vendredi")
        .when(col("most_active_day") == 7, "samedi")
    )
    
    return most_purchased_brand, most_purchased_category, most_active_time, most_active_day

# Fonction principale de traitement
def main():
    # Chargement et préparation des données
    filtered_df = load_and_prepare_data(output_path)
    
    # Ajout de colonnes supplémentaires
    filtered_df = add_additional_columns(filtered_df)

    # Définir les périodes de temps
    now = filtered_df.select(spark_max("event_time")).collect()[0][0]
    last_2_months = now - pd.DateOffset(months=2)
    last_5_months = now - pd.DateOffset(months=5)
    last_7_months = now - pd.DateOffset(months=7)

    # Filtrer les données pour chaque période
    filtered_df_2m = filtered_df.filter(col("event_time") >= lit(last_2_months))
    filtered_df_5m = filtered_df.filter(col("event_time") >= lit(last_5_months))
    filtered_df_7m = filtered_df.filter(col("event_time") >= lit(last_7_months))

    # Calculer les statistiques pour chaque période
    stats_2m = compute_user_stats(filtered_df_2m, "2m")
    stats_5m = compute_user_stats(filtered_df_5m, "5m")
    stats_7m = compute_user_stats(filtered_df_7m, "7m")

    # Union des statistiques pour les différentes périodes
    stats_all = stats_2m.join(stats_5m, "user_id").join(stats_7m, "user_id")

    # Calculer les autres statistiques
    days_since_last_purchase, total_purchase_value, cart_abandonments = compute_other_stats(filtered_df, now)

    # Calculer les préférences (marque, catégorie) et les moments d'activité
    preferred_brand, preferred_category, most_active_time, most_active_day = compute_user_preferences_and_activity(filtered_df)

    # Finaliser et combiner les résultats
    user_stats_df = stats_all.join(days_since_last_purchase, "user_id") \
                             .join(total_purchase_value, "user_id") \
                             .join(cart_abandonments, "user_id", "left") \
                             .join(preferred_brand, "user_id", "left") \
                             .join(preferred_category, "user_id", "left") \
                             .join(most_active_time, "user_id", "left") \
                             .join(most_active_day, "user_id", "left")

    # Affichage du DataFrame final
    user_stats_df.show()

    # # Affichage du nombre de lignes et de colonnes du DataFrame
    # print(f"Nombre de lignes : {user_stats_df.count()}")
    # print(f"Nombre de colonnes : {len(user_stats_df.columns)}")

# Enregistrer le DataFrame final en format Parquet avec suppression de l'existant
    user_stats_df.write.mode("overwrite").parquet("./data/user_stats_df_output.parquet")


# Exécuter le script principal
if __name__ == "__main__":
    main()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/02 05:45:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +---------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+-------------------+------------------------+--------------------+-----------------+---------------+--------------------+----------------+---------------+
# |  user_id|number_of_views_2m|number_of_carts_2m|number_of_sessions_2m|count_products_2m|avg_price_2m|number_of_views_5m|number_of_carts_5m|number_of_sessions_5m|count_products_5m|avg_price_5m|number_of_views_7m|number_of_carts_7m|number_of_sessions_7m|count_products_7m|avg_price_7m|      last_purchase|days_since_last_purchase|total_purchase_value|cart_abandonments|preferred_brand|  preferred_category|most_active_time|most_active_day|
# +---------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+-------------------+------------------------+--------------------+-----------------+---------------+--------------------+----------------+---------------+
# |359242441|                75|                 4|                    9|                1|       56.63|                75|                 4|                    9|                1|       56.63|                75|                 4|                    9|                1|       56.63|2020-04-11 08:08:14|                      19|               56.63|                3|        tp-link|furniture.kitchen...|         morning|       vendredi|
# |438263431|               138|                 4|                   46|                3|        81.7|               324|                 5|                  123|                4|      173.74|               331|                 5|                  128|                4|      173.74|2020-04-19 18:41:51|                      11|              694.95|                1|       aerocool|                NULL|       afternoon|         samedi|
# |469107971|                 2|                 1|                    1|                1|       229.5|                 2|                 1|                    1|                1|       229.5|                 2|                 1|                    1|                1|       229.5|2020-04-25 13:48:42|                       5|               229.5|                0|           NULL|                NULL|       afternoon|         samedi|
# |472393541|                 4|                 1|                    2|                1|      408.66|                 9|                 1|                    4|                1|      408.66|                 9|                 1|                    4|                1|      408.66|2020-03-17 10:00:04|                      44|              408.66|                0|          apple|construction.tool...|         morning|          mardi|
# |478219391|                16|                 8|                    4|                1|      254.58|                28|                 9|                    6|                1|      254.58|                29|                 9|                    7|                1|      254.58|2020-04-24 12:47:54|                       6|              254.58|                8|        samsung|apparel.shoes.sli...|         morning|          lundi|
# |480165611|                 6|                 2|                    5|                2|      257.77|                92|                 6|                   52|                4|       209.9|               102|                 7|                   59|                4|       209.9|2020-04-06 05:53:00|                      24|              839.61|                3|         orient|  electronics.clocks|           night|          jeudi|
# |487774501|                 3|                 1|                    1|                1|      241.84|                 4|                 1|                    2|                1|      241.84|                 5|                 1|                    3|                1|      241.84|2020-03-03 18:33:01|                      58|              241.84|                0|        samsung|construction.tool...|         evening|          mardi|
# |490293331|               101|                21|                   90|               16|      895.48|               997|                76|                  716|               58|      736.92|              1061|                83|                  775|               66|      755.97|2020-03-18 06:07:43|                      43|            49894.18|               17|           sony|appliances.person...|           night|          lundi|
WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.rpc.RpcTimeoutException: Cannot receive any reply from 78ff3e91b042:39015 in 10000 milliseconds. This timeout is controlled by spark.executor.heartbeatInterval
# 	at org.apache.spark.rpc.RpcTimeout.org$apache$spark$rpc$RpcTimeout$$createRpcTimeoutException(RpcTimeout.scala:47)
# 	at org.apache.spark.rpc.RpcTimeout$$anonfun$addMessageIfTimeout$1.applyOrElse(RpcTimeout.scala:62)
# 	at org.apache.spark.rpc.RpcTimeout$$anonfun$addMessageIfTimeout$1.applyOrElse(RpcTimeout.scala:58)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:38)
# 	at scala.util.Failure.recover(Try.scala:234)
# 	at scala.concurrent.Future.$anonfun$recover$1(Future.scala:395)
# 	at scala.concurrent.impl.Promise.liftedTree1$1(Promise.scala:33)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.tryFailure(Promise.scala:112)
# 	at scala.concurrent.Promise.tryFailure$(Promise.scala:112)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryFailure(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.org$apache$spark$rpc$netty$NettyRpcEnv$$onFailure$1(NettyRpcEnv.scala:214)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv$$anon$1.run(NettyRpcEnv.scala:264)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:304)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: java.util.concurrent.TimeoutException: Cannot receive any reply from 78ff3e91b042:39015 in 10000 milliseconds
# 	at org.apache.spark.rpc.netty.NettyRpcEnv$$anon$1.run(NettyRpcEnv.scala:265)
# 	... 6 more
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN SparkContext: Killing executors is not supported by current scheduler.
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: true
# 24/09/03 05:32:24 WARN NettyRpcEnv: Ignored message: HeartbeatResponse(true)
# 24/09/03 05:32:24 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:39015
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# ...
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 24/09/03 05:32:26 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:39015
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/09/03 05:32:26 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@78ff3e91b042:39015
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 24/09/03 05:32:26 ERROR Executor: Exit as unable to send heartbeats to driver more than 60 times

# %%
def main():
    # Chargement et préparation des données
    filtered_df = load_and_prepare_data(output_path)
    
    # Ajout de colonnes supplémentaires
    filtered_df = add_additional_columns(filtered_df)

    # Définir les périodes de temps
    now = filtered_df.select(spark_max("event_time")).collect()[0][0]
    last_2_months = now - pd.DateOffset(months=2)
    last_5_months = now - pd.DateOffset(months=5)
    last_7_months = now - pd.DateOffset(months=7)

    # Filtrer les données pour chaque période
    filtered_df_2m = filtered_df.filter(col("event_time") >= lit(last_2_months))
    filtered_df_5m = filtered_df.filter(col("event_time") >= lit(last_5_months))
    filtered_df_7m = filtered_df.filter(col("event_time") >= lit(last_7_months))

    # Calculer les statistiques pour chaque période
    stats_2m = compute_user_stats(filtered_df_2m, "2m")
    stats_5m = compute_user_stats(filtered_df_5m, "5m")
    stats_7m = compute_user_stats(filtered_df_7m, "7m")

    # Union des statistiques pour les différentes périodes
    stats_all = stats_2m.join(stats_5m, "user_id").join(stats_7m, "user_id")

    # Calculer les autres statistiques
    days_since_last_purchase, total_purchase_value, cart_abandonments = compute_other_stats(filtered_df, now)

    # Calculer les préférences (marque, catégorie) et les moments d'activité
    preferred_brand, preferred_category, most_active_time, most_active_day = compute_user_preferences_and_activity(filtered_df)

    # Finaliser et combiner les résultats
    user_stats_df = stats_all.join(days_since_last_purchase, "user_id") \
                             .join(total_purchase_value, "user_id") \
                             .join(cart_abandonments, "user_id", "left") \
                             .join(preferred_brand, "user_id", "left") \
                             .join(preferred_category, "user_id", "left") \
                             .join(most_active_time, "user_id", "left") \
                             .join(most_active_day, "user_id", "left")

   # Affichage du DataFrame final
    user_stats_df.show()

    # # Affichage du nombre de lignes et de colonnes du DataFrame
    # print(f"Nombre de lignes : {user_stats_df.count()}")
    # print(f"Nombre de colonnes : {len(user_stats_df.columns)}")

# Enregistrer le DataFrame final en format Parquet avec suppression de l'existant
    user_stats_df.write.mode("overwrite").parquet("./data/user_stats_df_output.parquet")

if __name__ == "__main__":
    main()

# %%
# Exécuter le script principal
if __name__ == "__main__":
    main()
# Out:
# [Stage 432:>                                                        (0 + 1) / 1]
# +---------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+-------------------+------------------------+--------------------+-----------------+---------------+--------------------+----------------+---------------+
# |  user_id|number_of_views_2m|number_of_carts_2m|number_of_sessions_2m|count_products_2m|avg_price_2m|number_of_views_5m|number_of_carts_5m|number_of_sessions_5m|count_products_5m|avg_price_5m|number_of_views_7m|number_of_carts_7m|number_of_sessions_7m|count_products_7m|avg_price_7m|      last_purchase|days_since_last_purchase|total_purchase_value|cart_abandonments|preferred_brand|  preferred_category|most_active_time|most_active_day|
# +---------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+------------------+------------------+---------------------+-----------------+------------+-------------------+------------------------+--------------------+-----------------+---------------+--------------------+----------------+---------------+
# |359242441|                75|                 4|                    9|                1|       56.63|                75|                 4|                    9|                1|       56.63|                75|                 4|                    9|                1|       56.63|2020-04-11 08:08:14|                      19|               56.63|                3|        tp-link|furniture.kitchen...|         morning|       vendredi|
# |438263431|               138|                 4|                   46|                3|        81.7|               324|                 5|                  123|                4|      173.74|               331|                 5|                  128|                4|      173.74|2020-04-19 18:41:51|                      11|              694.95|                1|       aerocool|                NULL|         evening|         samedi|
# |469107971|                 2|                 1|                    1|                1|       229.5|                 2|                 1|                    1|                1|       229.5|                 2|                 1|                    1|                1|       229.5|2020-04-25 13:48:42|                       5|               229.5|                0|           NULL|                NULL|       afternoon|         samedi|
# |472393541|                 4|                 1|                    2|                1|      408.66|                 9|                 1|                    4|                1|      408.66|                 9|                 1|                    4|                1|      408.66|2020-03-17 10:00:04|                      44|              408.66|                0|          apple|construction.tool...|         morning|          mardi|
# |478219391|                16|                 8|                    4|                1|      254.58|                28|                 9|                    6|                1|      254.58|                29|                 9|                    7|                1|      254.58|2020-04-24 12:47:54|                       6|              254.58|                8|        samsung|apparel.shoes.sli...|         morning|          lundi|
# |480165611|                 6|                 2|                    5|                2|      257.77|                92|                 6|                   52|                4|       209.9|               102|                 7|                   59|                4|       209.9|2020-04-06 05:53:00|                      24|              839.61|                3|         orient|  electronics.clocks|         evening|          jeudi|
# |487774501|                 3|                 1|                    1|                1|      241.84|                 4|                 1|                    2|                1|      241.84|                 5|                 1|                    3|                1|      241.84|2020-03-03 18:33:01|                      58|              241.84|                0|        samsung|construction.tool...|         evening|          mardi|
